# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the Dataset

# %%
retail=pd.read_csv('C:\\Users\\valivetirajesh\\DATASETS\\retail_data.csv',encoding='latin-1')

# %%
retail
# Out:
#         Month Enquiry Date      Enquiry Id Allocation Status Status  \
# 0    April'16    02-Apr-16   EC02041646800            Dealer    Won
# 1    April'16    08-Apr-16   EC08041647157            Dealer   Lost
# 2    April'16    08-Apr-16   EC08041647130            Dealer   Lost
# 3    April'16    09-Apr-16   EC09041647202            Direct   Lost
# 4    April'16    11-Apr-16   EC11041647360            Direct    Won
# 5    April'16    11-Apr-16   EC11041647280            Dealer   Lost
# 6    April'16    12-Apr-16   EC12041647460            Dealer   Lost
# 7    April'16    12-Apr-16   EC12041647402            Dealer   Lost
# 8    April'16    14-Apr-16   EC13041647531            Dealer   Lost
# 9    April'16    15-Apr-16   EC15041647749            Dealer   Lost
# 10   April'16    15-Apr-16   EC15041647740            Dealer   Lost
# 11   April'16    17-Apr-16   EC17041647818            Dealer   Lost
# 12   April'16    17-Apr-16   EC17041647824            Dealer    Won
# ...

# %%
retail.head()
# Out:
#       Month Enquiry Date      Enquiry Id Allocation Status Status      State  \
# 0  April'16    02-Apr-16   EC02041646800            Dealer    Won  TAMILNADU
# 1  April'16    08-Apr-16   EC08041647157            Dealer   Lost  TAMILNADU
# 2  April'16    08-Apr-16   EC08041647130            Dealer   Lost  TAMILNADU
# 3  April'16    09-Apr-16   EC09041647202            Direct   Lost  TAMILNADU
# 4  April'16    11-Apr-16   EC11041647360            Direct    Won  TAMILNADU
#
#           City  Pincode   Type of Project No of Windows          ...           \
# 0      CHENNAI   600008        Renovation       6 to 10          ...
# 1      CHENNAI   600042  New Construction       6 to 10          ...
# 2      CHENNAI   600015  New Construction        1 to 5          ...
# 3  KANCHIPURAM   600075  New Construction      21 to 40          ...
# 4      CHENNAI   600041        Renovation       6 to 10          ...
#
#   Second Action-Call Status.1         Remarks Price Per Sft  \
# ...

# %%
retail.tail()
# Out:
#       Month Enquiry Date     Enquiry Id Allocation Status Status      State  \
# 224  Jan'17    21-Jan-17  EC21011770512            Dealer   Lost  TAMILNADU
# 225  Jan'17    23-Jan-17  EC24011770882            Direct    Won  TAMILNADU
# 226  Jan'17    26-Jan-17  EC26121667587            Direct   Lost  TAMILNADU
# 227  Jan'17    27-Jan-17  EC27011771169            Dealer   Lost  TAMILNADU
# 228  Jan'17    27-Jan-17  EC27011771160            Direct   Lost  TAMILNADU
#
#             City  Pincode   Type of Project No of Windows  \
# 224      CHENNAI   600014        Renovation      11 to 20
# 225      CHENNAI   600015        Renovation        1 to 5
# 226      CHENNAI   600119        Renovation        1 to 5
# 227      CHENNAI   600082        Renovation        1 to 5
# 228  KANCHIPURAM   600089  New Construction        1 to 5
#
#              ...          Second Action-Call Status.1               Remarks  \
# 224          ...                                  NaN           Price Issue
# ...

# %%
retail.describe()
# Out:
#              Pincode  Q Val. (Rs. Lac)  Order Val. (Rs. Lac)  Order QTY  \
# count     229.000000        183.000000             48.000000  48.000000
# mean   601742.572052          1.842459              1.874375  10.229167
# std      6573.378113          2.595590              2.313372  14.925688
# min    600001.000000          0.010000              0.070000   1.000000
# 25%    600033.000000          0.550000              0.530000   2.000000
# 50%    600059.000000          1.070000              1.150000   6.000000
# 75%    600099.000000          2.000000              1.622500  10.500000
# max    635810.000000         25.000000             10.950000  73.000000
#
#        Second Action-Call Status.1  Price Per Sft  Aesthetics  \
# count                          0.0     229.000000   37.000000
# mean                           NaN    1045.323144    0.243243
# std                            NaN     220.032076    0.434959
# min                            NaN     650.000000    0.000000
# ...

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 40 columns):
# Month                                        229 non-null object
# Enquiry Date                                 229 non-null object
# Enquiry Id                                   229 non-null object
# Allocation Status                            229 non-null object
# Status                                       229 non-null object
# State                                        229 non-null object
# City                                         229 non-null object
# Pincode                                      229 non-null int64
# Type of Project                              229 non-null object
# No of Windows                                229 non-null object
# Source                                       229 non-null object
# Zone                                         229 non-null object
# Dealer Name                                  229 non-null object
# ...

# %%
type(retail['Quote QTY'])
# Out:
# pandas.core.series.Series

# %%
retail['Dealer Name']
# Out:
# 0         Sunbird
# 1      Winfratech
# 2         Sunbird
# 3          Direct
# 4         Sunbird
# 5      Rajtechnis
# 6         Sunbird
# 7        Windoors
# 8         Sunbird
# 9         Sunbird
# 10       Windoors
# 11        Sunbird
# 12        Sunbird
# 13     Rajtechnis
# 14        Sunbird
# 15        Sunbird
# 16        Sunbird
# 17           OXXO
# 18     Winfratech
# 19       Windoors
# 20       Windoors
# 21     Rajtechnis
# 22        Sunbird
# 23     Winfratech
# 24        Sunbird
# 25       Windoors
# 26     Rajtechnis
# 27       Windoors
# 28       Pearlson
# 29       Windoors
#           ...
# 199        Direct
# 200        Direct
# 201      pearlson
# 202        Direct
# 203        Direct
# 204      Windoors
# 205        Direct
# 206        Direct
# 207        Direct
# 208        Direct
# 209        Direct
# 210      Windoors
# 211        Direct
# 212      Windoors
# 213        Direct
# 214        Direct
# 215       Sunbird
# 216          OXXO
# 217          OXXO
# ...

# %%
retail['Dealer Name'].unique()
# Out:
# array(['Sunbird', 'Winfratech', 'Direct', 'Rajtechnis', 'Windoors',
#        'OXXO', 'Pearlson', 'ITP', 'pearlson'], dtype=object)

# %%
retail_d=retail[retail['Allocation Status']=='Dealer']

# %%
retail_d
# Out:
#         Month Enquiry Date       Enquiry Id Allocation Status Status  \
# 0    April'16    02-Apr-16    EC02041646800            Dealer    Won
# 1    April'16    08-Apr-16    EC08041647157            Dealer   Lost
# 2    April'16    08-Apr-16    EC08041647130            Dealer   Lost
# 5    April'16    11-Apr-16    EC11041647280            Dealer   Lost
# 6    April'16    12-Apr-16    EC12041647460            Dealer   Lost
# 7    April'16    12-Apr-16    EC12041647402            Dealer   Lost
# 8    April'16    14-Apr-16    EC13041647531            Dealer   Lost
# 9    April'16    15-Apr-16    EC15041647749            Dealer   Lost
# 10   April'16    15-Apr-16    EC15041647740            Dealer   Lost
# 11   April'16    17-Apr-16    EC17041647818            Dealer   Lost
# 12   April'16    17-Apr-16    EC17041647824            Dealer    Won
# 13   April'16    18-Apr-16    EC18041647862            Dealer   Lost
# 14   April'16    18-Apr-16    EC18041647914            Dealer    Won
# ...

# %%
retail_d1=retail_d.loc[:,['Allocation Status','Dealer Name','Status','No of Windows','Order QTY']]

# %%
retail_d1
# Out:
#     Allocation Status Dealer Name Status No of Windows  Order QTY
# 0              Dealer     Sunbird    Won       6 to 10        3.0
# 1              Dealer  Winfratech   Lost       6 to 10        NaN
# 2              Dealer     Sunbird   Lost        1 to 5        NaN
# 5              Dealer  Rajtechnis   Lost        1 to 5        NaN
# 6              Dealer     Sunbird   Lost      11 to 20        NaN
# 7              Dealer    Windoors   Lost       6 to 10        NaN
# 8              Dealer     Sunbird   Lost        1 to 5        NaN
# 9              Dealer     Sunbird   Lost       6 to 10        NaN
# 10             Dealer    Windoors   Lost        1 to 5        NaN
# 11             Dealer     Sunbird   Lost     41 to 100        NaN
# 12             Dealer     Sunbird    Won        1 to 5        5.0
# 13             Dealer  Rajtechnis   Lost        1 to 5        NaN
# 14             Dealer     Sunbird    Won       6 to 10        7.0
# ...

# %%
retail_d1[retail_d1['Status']=='Lost'].count()
# Out:
# Allocation Status    137
# Dealer Name          137
# Status               137
# No of Windows        137
# Order QTY              0
# dtype: int64

# %%
retail_d1[retail_d1['Status']=='Won'].count()
# Out:
# Allocation Status    28
# Dealer Name          28
# Status               28
# No of Windows        28
# Order QTY            26
# dtype: int64

# %%
sns.countplot(x='Status',data=retail_d1)
plt.show()

# %% [markdown]
# # Data Cleaning

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 40 columns):
# Month                                        229 non-null object
# Enquiry Date                                 229 non-null object
# Enquiry Id                                   229 non-null object
# Allocation Status                            229 non-null object
# Status                                       229 non-null object
# State                                        229 non-null object
# City                                         229 non-null object
# Pincode                                      229 non-null int64
# Type of Project                              229 non-null object
# No of Windows                                229 non-null object
# Source                                       229 non-null object
# Zone                                         229 non-null object
# Dealer Name                                  229 non-null object
# ...

# %%
retail['Dealer Name'].unique()
# Out:
# array(['Sunbird', 'Winfratech', 'Direct', 'Rajtechnis', 'Windoors',
#        'OXXO', 'Pearlson', 'ITP', 'pearlson'], dtype=object)

# %%
retail_d=retail[retail['Allocation Status']=='Dealer']

# %%
retail_d.drop(retail[(retail['Dealer Name']=='Direct')&(retail['Allocation Status']=='Dealer')].index,inplace=True)
# Out:
# C:\Users\valivetirajesh\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
retail_d['Dealer Name'].unique()
# Out:
# array(['Sunbird', 'Winfratech', 'Rajtechnis', 'Windoors', 'OXXO', 'ITP',
#        'Pearlson', 'pearlson'], dtype=object)

# %%
retail_d['Allocation Status'].unique()
# Out:
# array(['Dealer'], dtype=object)

# %%
retail_d['Dealer Name'][retail['Dealer Name']=='pearlson']='Pearlson'
# Out:
# C:\Users\valivetirajesh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\valivetirajesh\Anaconda3\lib\site-packages\pandas\core\generic.py:7626: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\valivetirajesh\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3267: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
retail_d['Dealer Name'].nunique()
# Out:
# 7

# %%
retail_d['Allocation Status'].unique()
# Out:
# array(['Dealer'], dtype=object)

# %%
retail_d['Status'].unique()
# Out:
# array(['Won', 'Lost'], dtype=object)

# %%
retail_d['State'].unique()
# Out:
# array(['TAMILNADU'], dtype=object)

# %%
retail_d['City'].unique()
# Out:
# array(['CHENNAI', 'VELLORE', 'THIRUVALLUR', 'KANCHIPURAM', 'CUDDALORE',
#        'KRISHNAGIRI', 'VILLUPURAM', 'TIRUVANNAMALAI'], dtype=object)

# %%
retail_d['Type of Project'].unique()
# Out:
# array(['Renovation', 'New Construction'], dtype=object)

# %%
retail_d['No of Windows'].unique()
# Out:
# array(['6 to 10', '1 to 5', '11 to 20', '41 to 100', '21 to 40'],
#       dtype=object)

# %%
retail_d['Source'].unique()
# Out:
# array(['Friends or Family  ', 'Just dial', 'Current User', 'Internet'],
#       dtype=object)

# %%
retail_d['Zone'].unique()
# Out:
# array(['Chennai', 'Kanchipuram'], dtype=object)

# %%
retail_d['Zone'].value_counts()
# Out:
# Chennai        160
# Kanchipuram      1
# Name: Zone, dtype: int64

# %%
retail_d['Zone'].replace({'Kanchipuram':'Chennai'},inplace=True)
# Out:
# C:\Users\valivetirajesh\Anaconda3\lib\site-packages\pandas\core\generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
retail_d['Zone'].value_counts()
# Out:
# Chennai    161
# Name: Zone, dtype: int64

# %%
retail_d['First Action-Call made'].unique()
# Out:
# array(['Yes'], dtype=object)

# %%
retail_d['Second Action-Customer Meeting'].unique()
# Out:
# array(['yes', nan, 'YES'], dtype=object)

# %%
retail_d['Second Action-Customer Meeting'].value_counts()
# Out:
# yes    116
# YES     16
# Name: Second Action-Customer Meeting, dtype: int64

# %%
retail_d['Second Action-Customer Meeting'].replace({'YES':'yes'},inplace=True)

# %%
retail_d['Second Action-Customer Meeting'].value_counts()
# Out:
# yes    132
# Name: Second Action-Customer Meeting, dtype: int64

# %%
retail_d['Second Action-Call Status'].value_counts()
# Out:
# Quote to Be Submitted       129
# Design not Feasible           1
# Further Meeting Required      1
# Name: Second Action-Call Status, dtype: int64

# %%
retail_d['Third Action-Quote Given'].value_counts()
# Out:
# yes    114
# YES     15
# Name: Third Action-Quote Given, dtype: int64

# %%
retail_d['Third Action-Quote Given'].replace({'YES':'yes'},inplace=True)

# %%
retail_d['Third Action-Quote Given'].value_counts()
# Out:
# yes    129
# Name: Third Action-Quote Given, dtype: int64

# %%
retail_d['Third Action-Quote Given'].value_counts()
# Out:
# yes    129
# Name: Third Action-Quote Given, dtype: int64

# %%
retail_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161 entries, 0 to 227
# Data columns (total 40 columns):
# Month                                        161 non-null object
# Enquiry Date                                 161 non-null object
# Enquiry Id                                   161 non-null object
# Allocation Status                            161 non-null object
# Status                                       161 non-null object
# State                                        161 non-null object
# City                                         161 non-null object
# Pincode                                      161 non-null int64
# Type of Project                              161 non-null object
# No of Windows                                161 non-null object
# Source                                       161 non-null object
# Zone                                         161 non-null object
# Dealer Name                                  161 non-null object
# ...

# %%
retail_d
# Out:
#         Month Enquiry Date      Enquiry Id Allocation Status Status  \
# 0    April'16    02-Apr-16   EC02041646800            Dealer    Won
# 1    April'16    08-Apr-16   EC08041647157            Dealer   Lost
# 2    April'16    08-Apr-16   EC08041647130            Dealer   Lost
# 5    April'16    11-Apr-16   EC11041647280            Dealer   Lost
# 6    April'16    12-Apr-16   EC12041647460            Dealer   Lost
# 7    April'16    12-Apr-16   EC12041647402            Dealer   Lost
# 8    April'16    14-Apr-16   EC13041647531            Dealer   Lost
# 9    April'16    15-Apr-16   EC15041647749            Dealer   Lost
# 10   April'16    15-Apr-16   EC15041647740            Dealer   Lost
# 11   April'16    17-Apr-16   EC17041647818            Dealer   Lost
# 12   April'16    17-Apr-16   EC17041647824            Dealer    Won
# 13   April'16    18-Apr-16   EC18041647862            Dealer   Lost
# 14   April'16    18-Apr-16   EC18041647914            Dealer    Won
# ...

# %% [markdown]
# # Dealerwise Performance Analysis

# %%
def f(x):
    return Series(dict(Won=x[x['Status']=='Won']['Status'].count(),
                       Lost=x[x['Status']=='Lost']['Status'].count()
                      ))
f(retail_d)
# Out:
# Won      26
# Lost    135
# dtype: int64

# %%
dealerwise=retail_d.groupby('Dealer Name').apply(f)

# %%
dealerwise
# Out:
#              Won  Lost
# Dealer Name
# ITP            0    13
# OXXO           4    16
# Pearlson       4    11
# Rajtechnis     1    14
# Sunbird        9    24
# Windoors       6    39
# Winfratech     2    18

# %%
sns.countplot(x='Dealer Name',data=retail_d,hue='Status')
plt.xticks(rotation=45)
plt.show()

# %%
dealerwise['Win%']=list(map(lambda x,y:x*100/(x+y),dealerwise['Won'],dealerwise['Lost']))

# %%
dealerwise
# Out:
#              Won  Lost       Win%
# Dealer Name
# ITP            0    13   0.000000
# OXXO           4    16  20.000000
# Pearlson       4    11  26.666667
# Rajtechnis     1    14   6.666667
# Sunbird        9    24  27.272727
# Windoors       6    39  13.333333
# Winfratech     2    18  10.000000

# %%
dealerwise['Win%'].mean()
# Out:
# 14.848484848484848

# %% [markdown]
# # Performers

# %%
goodeff=dealerwise[dealerwise['Win%']>dealerwise['Win%'].mean()]

# %%
goodeff
# Out:
#              Won  Lost       Win%
# Dealer Name
# OXXO           4    16  20.000000
# Pearlson       4    11  26.666667
# Sunbird        9    24  27.272727

# %% [markdown]
# # Non Performers

# %%
badeff=dealerwise[dealerwise['Win%']<dealerwise['Win%'].mean()]

# %%
badeff
# Out:
#              Won  Lost       Win%
# Dealer Name
# ITP            0    13   0.000000
# Rajtechnis     1    14   6.666667
# Windoors       6    39  13.333333
# Winfratech     2    18  10.000000

# %%
badeff.reset_index(level=0,inplace=True)

# %%
badeff
# Out:
#   Dealer Name  Won  Lost       Win%
# 0         ITP    0    13   0.000000
# 1  Rajtechnis    1    14   6.666667
# 2    Windoors    6    39  13.333333
# 3  Winfratech    2    18  10.000000

# %% [markdown]
# # Issue Analysis

# %%
retail_d['Remarks'].value_counts()
# Out:
# Price Issue                      79
# Budget Constraint                20
# Design Infeasibility             20
# Price issue                       3
# Delivery Issue                    2
# Design Infeasibe My               1
# Others                            1
# No Requirment                     1
# Delivery Issve                    1
# Design Not Feasible               1
# No Requirement-Awareness Call     1
# Name: Remarks, dtype: int64

# %%
retail_d.replace({'Price issue':'Price Issue', 'Design Infeasibe My':'Design Infeasibility','Design Not Feasible':'Design Infeasibility',
                 'Delivery Issve':'Delivery Issue','No Requirment':'No Requirement-Awareness Call'},inplace=True)
# Out:
# C:\Users\valivetirajesh\Anaconda3\lib\site-packages\pandas\core\frame.py:3798: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)

# %%
retail_d['Remarks'].value_counts()
# Out:
# Price Issue                      82
# Design Infeasibility             22
# Budget Constraint                20
# Delivery Issue                    3
# No Requirement-Awareness Call     2
# Others                            1
# Name: Remarks, dtype: int64

# %%
plt.subplots(figsize=(16,8))
sns.countplot(x='Dealer Name',data=retail_d,hue='Remarks')
plt.show()

# %% [raw]
# # Price issue is the major issue for losing the orders

# %% [markdown]
# Benefits:

# %%
plt.plot(retail_d['Dealer Name'].index,retail_d['Price Per Sft'])
plt.show()

# %%
sns.distplot(retail_d['Price Per Sft'],kde=True)
# Out:
# C:\Users\valivetirajesh\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
a=retail_d[retail_d['Status']=='Won']

# %%
b=retail_d[retail_d['Status']=='Lost']

# %%
b
# Out:
#         Month Enquiry Date      Enquiry Id Allocation Status Status  \
# 1    April'16    08-Apr-16   EC08041647157            Dealer   Lost
# 2    April'16    08-Apr-16   EC08041647130            Dealer   Lost
# 5    April'16    11-Apr-16   EC11041647280            Dealer   Lost
# 6    April'16    12-Apr-16   EC12041647460            Dealer   Lost
# 7    April'16    12-Apr-16   EC12041647402            Dealer   Lost
# 8    April'16    14-Apr-16   EC13041647531            Dealer   Lost
# 9    April'16    15-Apr-16   EC15041647749            Dealer   Lost
# 10   April'16    15-Apr-16   EC15041647740            Dealer   Lost
# 11   April'16    17-Apr-16   EC17041647818            Dealer   Lost
# 13   April'16    18-Apr-16   EC18041647862            Dealer   Lost
# 15   April'16    19-Apr-16   EC19041648005            Dealer   Lost
# 16   April'16    20-Apr-16   EC20041648053            Dealer   Lost
# 19   April'16    22-Apr-16   EC22041648210            Dealer   Lost
# ...

# %%
a['Benefits'].value_counts()
# Out:
# Reduce Street Noise                      6
# Nil                                      5
# Reduce AC Energy Cost & Street Noise     4
# Aesthetics & Low Maintenance             3
# Low Maintenance                          2
# Aesthetics & Street Noise                1
# Noise Proof & Better Lighting            1
# Reduce Street Noise & Low Maintenance    1
# Low Maintenance & Aesthetics             1
# nil                                      1
# Reduce Street noise                      1
# Name: Benefits, dtype: int64

# %%
a
# Out:
#         Month Enquiry Date     Enquiry Id Allocation Status Status      State  \
# 0    April'16    02-Apr-16  EC02041646800            Dealer    Won  TAMILNADU
# 12   April'16    17-Apr-16  EC17041647824            Dealer    Won  TAMILNADU
# 14   April'16    18-Apr-16  EC18041647914            Dealer    Won  TAMILNADU
# 17   April'16    21-Apr-16  EC21041648143            Dealer    Won  TAMILNADU
# 18   April'16    21-Apr-16  EC21041648139            Dealer    Won  TAMILNADU
# 20   April'16    22-Apr-16  EC21041648139            Dealer    Won  TAMILNADU
# 36    June'16    18-Jun-16  EC18061652454            Dealer    Won  TAMILNADU
# 39    June'16    20-Jun-16  EC20061652630            Dealer    Won  TAMILNADU
# 78    July'16    27-Jul-16  EC27071655362            Dealer    Won  TAMILNADU
# 89     Aug'16    03-Aug-16  EC03081655949            Dealer    Won  TAMILNADU
# 96     Aug'16    08-Aug-16  EC08081656257            Dealer    Won  TAMILNADU
# ...

# %%
plt.subplots(figsize=(16,8))
sns.countplot(x='Month',data=b,hue='Dealer Name')
plt.title('Month Vs Lost count / Dealer Name wise')
plt.grid()
plt.show()

# %%
plt.subplots(figsize=(16,14))

plt.subplot(2,1,1)
sns.countplot(x='Month',data=a,hue='Dealer Name')
plt.title('Month vs Won count / Dealer Name wise')
plt.grid()
plt.show()

plt.subplots(figsize=(16,14))
plt.subplot(2,1,2)
sns.countplot(x='Month',data=b,hue='Dealer Name',hue_order=['Sunbird','OXXO','Winfratech','Windoors','Pearlson','Rajtechnics'])
plt.title('Month vs Lost count / Dealer Name wise')
plt.grid()
plt.show()

# %%
sns.countplot(x='Month',hue='Status',data=retail_d)
plt.title('Month Vs Status')
plt.grid()
plt.show()

# %% [raw]
# # July has more number of enquiries and more lost deals

# %%
retail_d.iloc[10:18]['Dealer Name']
# Out:
# 12       Sunbird
# 13    Rajtechnis
# 14       Sunbird
# 15       Sunbird
# 16       Sunbird
# 17          OXXO
# 18    Winfratech
# 19      Windoors
# Name: Dealer Name, dtype: object

# %%
retail_d['Dealer Name'].iloc[10:18]
# Out:
# 12       Sunbird
# 13    Rajtechnis
# 14       Sunbird
# 15       Sunbird
# 16       Sunbird
# 17          OXXO
# 18    Winfratech
# 19      Windoors
# Name: Dealer Name, dtype: object

# %%
plt.subplots(figsize=(20,10))
sns.swarmplot(x='Dealer Name',y='Price Per Sft',data=a,hue='Benefits',palette='bright',size=15.0)
plt.title('Dealer Name Vs Price Per Sft')
# Out:
# Text(0.5, 1.0, 'Dealer Name Vs Price Per Sft')

# %% [raw]
# # Above plot gives me an idea of which dealer is providing a particular benefit for best price

# %%
sns.countplot(x='Benefits',data=a)
plt.xticks(rotation=90)
plt.title('Benefits Vs count')
plt.grid()
plt.show()

# %% [raw]
# # Benefits with more count:
# 1)Reduce Street Noise - 7, 2)Reduce AC Energy Cost & Street Noise - 4, 3) Aesthetics & Low Maintainance - 3,
# 4)Low Maintenance- 2, 5)Reduce Street Noise & Low Maintenance,Low Maintenance, & Aesthetics, Noise Proof & Better Lighting - 1

# %%
plt.subplots(figsize=(20,10))
sns.countplot(x='Dealer Name',hue='Benefits',data=a,palette='bright')
plt.title('Dealer Name Vs count / Benefits Wise')
plt.grid()
plt.show()

# %% [raw]
# #Benefits variety count of company:
# Sunbird - 6, Oxxo - 3, Winfratech - 2, Windoors - 3, Pearlson - 3, Rajtechnis - 1

# %%
help(sns.swarmplot)
# Out:
# Help on function swarmplot in module seaborn.categorical:
#
# swarmplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)
#     Draw a categorical scatterplot with non-overlapping points.
#
#     This function is similar to :func:`stripplot`, but the points are adjusted
#     (only along the categorical axis) so that they don't overlap. This gives a
#     better representation of the distribution of values, but it does not scale
#     well to large numbers of observations. This style of plot is sometimes
#     called a "beeswarm".
#
#     A swarm plot can be drawn on its own, but it is also a good complement
#     to a box or violin plot in cases where you want to show all observations
#     along with some representation of the underlying distribution.
#
#     Arranging the points properly requires an accurate transformation between
# ...

# %%
retail_d['Benefits'].value_counts()
# Out:
# Reduce Street Noise                      6
# Nil                                      5
# Reduce AC Energy Cost & Street Noise     4
# Aesthetics & Low Maintenance             3
# Low Maintenance                          2
# Aesthetics & Street Noise                1
# Reduce Street noise                      1
# Noise Proof & Better Lighting            1
# Low Maintenance & Aesthetics             1
# nil                                      1
# Reduce Street Noise & Low Maintenance    1
# Name: Benefits, dtype: int64

# %%
a['Benefits'].replace({'Reduce Street noise':'Reduce Street Noise','nil':'Nil'},inplace=True)

# %%
retail_d['Benefits'].replace({'Reduce Street noise':'Reduce Street Noise','nil':'Nil'},inplace=True)

# %%
def f(x):
    b=dict(ReduceStreetNoise=x[x['Benefits']=='Reduce Street Noise']['Benefits'].count(),
                       Nil=x[x['Benefits']=='Nil']['Benefits'].count(),
           ReduceACEnergyCostStreetNoise=x[x['Benefits']=='Reduce AC Energy Cost & Street Noise']['Benefits'].count(), 
              
           AestheticsLowMaintenance=x[x['Benefits']=='Aesthetics & Low Maintenance']['Benefits'].count(),             
           LowMaintenance=x[x['Benefits']=='Low Maintenance']['Benefits'].count(),                           
           AestheticsStreetNoise=x[x['Benefits']=='Aesthetics & Street Noise']['Benefits'].count(),                
           ReduceStreetNoiseLowMaintenance=x[x['Benefits']=='Reduce Street Noise & Low Maintenance']['Benefits'].count(),    
           NoiseProofBetterLighting=x[x['Benefits']=='Noise Proof & Better Lighting']['Benefits'].count(),             
           LowMaintenanceAesthetics=x[x['Benefits']=='Low Maintenance & Aesthetics']['Benefits'].count())
    return Series(b)

# %%
ben=a.groupby('Dealer Name').apply(f)

# %%
ben
# Out:
#              ReduceStreetNoise  Nil  ReduceACEnergyCostStreetNoise  \
# Dealer Name
# OXXO                         2    0                              1
# Pearlson                     2    0                              0
# Rajtechnis                   0    0                              1
# Sunbird                      1    2                              2
# Windoors                     1    3                              0
# Winfratech                   1    1                              0
#
#              AestheticsLowMaintenance  LowMaintenance  AestheticsStreetNoise  \
# Dealer Name
# OXXO                                0               0                      0
# Pearlson                            1               1                      0
# Rajtechnis                          0               0                      0
# Sunbird                             1               1                      1
# Windoors                            1               0                      0
# ...

# %%
ben['Total']=ben.sum()

# %%
ben
# Out:
#              ReduceStreetNoise  Nil  ReduceACEnergyCostStreetNoise  \
# Dealer Name
# OXXO                         2    0                              1
# Pearlson                     2    0                              0
# Rajtechnis                   0    0                              1
# Sunbird                      1    2                              2
# Windoors                     1    3                              0
# Winfratech                   1    1                              0
#
#              AestheticsLowMaintenance  LowMaintenance  AestheticsStreetNoise  \
# Dealer Name
# OXXO                                0               0                      0
# Pearlson                            1               1                      0
# Rajtechnis                          0               0                      0
# Sunbird                             1               1                      1
# Windoors                            1               0                      0
# ...

# %%
ben['Total']=ben.iloc[:].sum(axis=1)

# %%
ben
# Out:
#              ReduceStreetNoise  Nil  ReduceACEnergyCostStreetNoise  \
# Dealer Name
# OXXO                         2    0                              1
# Pearlson                     2    0                              0
# Rajtechnis                   0    0                              1
# Sunbird                      1    2                              2
# Windoors                     1    3                              0
# Winfratech                   1    1                              0
#
#              AestheticsLowMaintenance  LowMaintenance  AestheticsStreetNoise  \
# Dealer Name
# OXXO                                0               0                      0
# Pearlson                            1               1                      0
# Rajtechnis                          0               0                      0
# Sunbird                             1               1                      1
# Windoors                            1               0                      0
# ...

# %%
retail_d.groupby(retail_d['Dealer Name'])['Q Val. (Rs. Lac)'].count()
# Out:
# Dealer Name
# ITP            8
# OXXO          18
# Pearlson       7
# Rajtechnis    12
# Sunbird       27
# Windoors      41
# Winfratech    11
# Name: Q Val. (Rs. Lac), dtype: int64

# %%
# Referrals

# %%
sns.countplot(x='Source',data=retail_d)

# %%
#Referrals through Internet are more in number

# %%
sns.countplot(x='Source',hue='Status',data=retail_d)

# %%
# More orders are won upon referral by Friends or Family than Internet which are more in number
